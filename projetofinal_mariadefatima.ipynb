# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Usei a função read_csv para importar o arquivo, realizarei a limpeza das informações que desejo trabalhar na análise de dados.

# %%
df_consentido_pais = pd.read_csv('datasets/consentido_pais.csv')
df_consentido_pais
# Out:
#     ID do indicador                  descrição do indicador  \
# 0         Ifdb90d43  Idade mínima legal para casar por sexo
# 1         Ifdb90d43  Idade mínima legal para casar por sexo
# 2         Ifdb90d43  Idade mínima legal para casar por sexo
# 3         Ifdb90d43  Idade mínima legal para casar por sexo
# 4         Ifdb90d43  Idade mínima legal para casar por sexo
# ..              ...                                     ...
# 186       Ifdb90d43  Idade mínima legal para casar por sexo
# 187       Ifdb90d43  Idade mínima legal para casar por sexo
# 188       Ifdb90d43  Idade mínima legal para casar por sexo
# 189       Ifdb90d43  Idade mínima legal para casar por sexo
# 190       Ifdb90d43  Idade mínima legal para casar por sexo
#
#                      descrição da série de mentalidade  area de referencia  \
# 0    Idade mínima para casamento legal - Com consen...                   8
# 1    Idade mínima para casamento legal - Com consen...                   8
# ...

# %%
df_consentido_pais.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ID do indicador                    191 non-null    object
#  1   descrição do indicador             191 non-null    object
#  2   descrição da série de mentalidade  191 non-null    object
#  3   area de referencia                 191 non-null    int64
#  4   descrição da area de refêrencia    191 non-null    object
#  5   iso3                               191 non-null    object
#  6   x                                  191 non-null    object
#  7   y                                  191 non-null    object
#  8   região ODS                         191 non-null    object
#  9   sexo                               191 non-null    object
#  10  descrição de sexo                  191 non-null    object
# ...

# %%
import pandas as pd

df_consentido_pais.isnull()
# Out:
#      ID do indicador  descrição do indicador  \
# 0              False                   False
# 1              False                   False
# 2              False                   False
# 3              False                   False
# 4              False                   False
# ..               ...                     ...
# 186            False                   False
# 187            False                   False
# 188            False                   False
# 189            False                   False
# 190            False                   False
#
#      descrição da série de mentalidade  area de referencia  \
# 0                                False               False
# 1                                False               False
# 2                                False               False
# 3                                False               False
# 4                                False               False
# ..                                 ...                 ...
# ...

# %%
df_consentido_pais.isnull().sum()
# Out:
# ID do indicador                        0
# descrição do indicador                 0
# descrição da série de mentalidade      0
# area de referencia                     0
# descrição da area de refêrencia        0
# iso3                                   0
# x                                      0
# y                                      0
# região ODS                             0
# sexo                                   0
# descrição de sexo                      0
# período de tempo                       0
# detalhe de tempo                       0
# modificador de valor obs             179
# valor de observação                    0
# nature                                 0
# observação de comentários            143
# source_detail                          0
# source_detail_url                      0
# source_year                            0
# dimensions                             0
# is_latest_year                         0
# dtype: int64

# %% [markdown]
#                                            Analisando os dados
#
# Começando a análise exploratória, farei a exclusão de algumas colunas que não irão interferir no resultado da análise.
#
# Tentei usar a função drop, excluia as colunas mas não imprimia. Entaão, identifiquei as colunas que eu queria excluir coma função df.columns e criando um novo DataFrame com as informaçoes que eu precisava.
#
# Excluindo as seguintes colunas:
# ID do indicador, descrição do indicador, descrição da série de mentalidade, isos3, source_detail_url,dimensions, is_latest_year.

# %%
df_consentido_pais.columns
# Out:
# Index(['ID do indicador', 'descrição do indicador',
#        'descrição da série de mentalidade', 'area de referencia',
#        'descrição da area de refêrencia', 'iso3', 'x', 'y', 'região ODS',
#        'sexo', 'descrição de sexo', 'período de tempo', 'detalhe de tempo',
#        'modificador de valor obs', 'valor de observação', 'nature',
#        'observação de comentários', 'source_detail', 'source_detail_url',
#        'source_year', 'dimensions', 'is_latest_year'],
#       dtype='object')

# %%
df_consentido = df_consentido_pais[['descrição da area de refêrencia', 'x', 'y', 'região ODS', 
              'sexo', 'detalhe de tempo', 'modificador de valor obs','valor de observação', 'observação de comentários', 'source_year']]
df_consentido
# Out:
#           descrição da area de refêrencia               x               y  \
# 0                                 Albânia   2.006.660.928   4.113.897.007
# 1                                 Albânia   2.006.660.928   4.113.897.007
# 2                                 Andorra   1.576.257.417   4.254.548.611
# 3                                 Andorra   1.576.257.417   4.254.548.611
# 4                                 Anguila  -6.305.651.612   1.821.525.315
# ..                                    ...             ...             ...
# 186                           Uzbequistão   6.311.944.558   4.177.560.518
# 187  Venezuela (República Bolivariana da)  -6.615.642.084   7.121.324.748
# 188  Venezuela (República Bolivariana da)  -6.615.642.084   7.121.324.748
# 189                              Zimbábue   2.986.909.584  -1.900.075.492
# 190                              Zimbábue   2.986.909.584  -1.900.075.492
#
#                     região ODS sexo detalhe de tempo modificador de valor obs  \
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd


#'Permissão de Casamento com Meninas < 15 anos'

df_consentido = pd.DataFrame(df_consentido)
df_consentido
# Contagem de países com e sem permissão para casamento com meninas menores de 15 anos

menor = df_consentido.loc[(['valor de observação']>18)]
menor = df_consentido['descrição da area de refêrencia'].value_counts()

# Criando o gráfico de barras
plt.figure(figsize=(12, 6))
counts.plot(kind='bar', color=['green', 'red'])
plt.title('Permissão de Casamento com Meninas Menores de 15 Anos por País')
plt.xlabel('Países')
plt.ylabel('Permissão de Casamento')
plt.xticks(rotation=330)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[127], line 11
#       8 df_consentido
#       9 # Contagem de países com e sem permissão para casamento com meninas menores de 15 anos
# ---> 11 menor = df_consentido.loc[(['valor de observação']>18)]
#      12 menor = df_consentido['descrição da area de refêrencia'].value_counts()
#      14 # Criando o gráfico de barras
#
# TypeError: '>' not supported between instances of 'list' and 'int'

# %%
# os países em que o casamento é permitido com meninas de idade inferior a 15 anos?
# Na américa latina, qual a idade para casamento legalizado?
# Quais os países na América Latina em que ocorrem casos com de casamentos com o consetimento dos pais.
# Quais os 15 países no mundo com maior incidencia de casamentos antes dos 18 anos de idade.

# %%
import matplotlib.pyplot as plt
contagem = df_consentido_pais[['descrição da area de refêrencia', 'valor de observação']].sort_values(by='valor de observação', ascending=False).head(15)
#Criando gráfico para mostrar os 15 países em que casamento antes dos 18 anos são permitidos
plt.figure(figsize=(12, 6))
plt.bar(contagem['descrição da area de refêrencia'], contagem['valor de observação'])
plt.xlabel('descrição da area de refêrencia')
plt.ylabel('valor de observação')
plt.title('Os 15 Países em que mais se tem casamentos antes dos 18 anos, com consentimento dos pais')

plt.xticks(rotation=45)

plt.show()

# %%
df_consentimento_negado = pd.read_csv('datasets/consentimento_negado.csv')
df_consentimento_negado
# Out:
#     indicator_label                  descrição do indicador  \
# 0              QV.4  Idade mínima legal para casar por sexo
# 1              QV.4  Idade mínima legal para casar por sexo
# 2              QV.4  Idade mínima legal para casar por sexo
# 3              QV.4  Idade mínima legal para casar por sexo
# 4              QV.4  Idade mínima legal para casar por sexo
# ..              ...                                     ...
# 250            QV.4  Idade mínima legal para casar por sexo
# 251            QV.4  Idade mínima legal para casar por sexo
# 252            QV.4  Idade mínima legal para casar por sexo
# 253            QV.4  Idade mínima legal para casar por sexo
# 254            QV.4  Idade mínima legal para casar por sexo
#
#                      descrição da série de mentalidade  \
# 0    Idade mínima para casamento legal – Sem consen...
# 1    Idade mínima para casamento legal – Sem consen...
# 2    Idade mínima para casamento legal – Sem consen...
# ...

# %%
df_consentimento_negado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 15 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   indicator_label                    255 non-null    object
#  1   descrição do indicador             255 non-null    object
#  2   descrição da série de mentalidade  255 non-null    object
#  3   area de referencia                 255 non-null    object
#  4   x                                  255 non-null    object
#  5   y                                  255 non-null    object
#  6   região ODS                         255 non-null    object
#  7   sexo                               255 non-null    object
#  8   descrição de sexo                  255 non-null    object
#  9   período de tempo                   255 non-null    int64
#  10  detalhe de tempo                   255 non-null    object
# ...

# %%
df_consentimento_negado.isnull()
# Out:
#      indicator_label  descrição do indicador  \
# 0              False                   False
# 1              False                   False
# 2              False                   False
# 3              False                   False
# 4              False                   False
# ..               ...                     ...
# 250            False                   False
# 251            False                   False
# 252            False                   False
# 253            False                   False
# 254            False                   False
#
#      descrição da série de mentalidade  area de referencia      x      y  \
# 0                                False               False  False  False
# 1                                False               False  False  False
# 2                                False               False  False  False
# 3                                False               False  False  False
# ...

# %%
df_consentimento_negado.isnull().sum()
# Out:
# indicator_label                        0
# descrição do indicador                 0
# descrição da série de mentalidade      0
# area de referencia                     0
# x                                      0
# y                                      0
# região ODS                             0
# sexo                                   0
# descrição de sexo                      0
# período de tempo                       0
# detalhe de tempo                       0
# valor de observação                    0
# observação de comentários            171
# source_detail_url                      0
# ano de origem                          0
# dtype: int64

# %%
df_consentimento_negado.columns
# Out:
# Index(['indicator_label', 'descrição do indicador',
#        'descrição da série de mentalidade', 'area de referencia', 'x', 'y',
#        'região ODS', 'sexo', 'descrição de sexo', 'período de tempo',
#        'detalhe de tempo', 'valor de observação', 'observação de comentários',
#        'source_detail_url', 'ano de origem'],
#       dtype='object')

# %%
df_negado = df_consentimento_negado[['area de referencia', 'x', 'y',
         'sexo', 'detalhe de tempo', 'valor de observação', 'observação de comentários', 'região ODS']]
df_negado
# Out:
#                        area de referencia               x               y  \
# 0                             Ilhas Aland   1.980.945.969     601.544.901
# 1                             Ilhas Aland   1.980.945.969     601.544.901
# 2                                 Albânia   2.006.660.928   4.113.897.007
# 3                                 Albânia   2.006.660.928   4.113.897.007
# 4                                 Andorra   1.576.257.417   4.254.548.611
# ..                                    ...             ...             ...
# 250  Venezuela (República Bolivariana da)  -6.615.642.084   7.121.324.748
# 251                                Vietnã     105.802.499   1.009.643.079
# 252                                Vietnã     105.802.499   1.009.643.079
# 253                              Zimbábue   2.986.909.584  -1.900.075.492
# 254                              Zimbábue   2.986.909.584  -1.900.075.492
#
#     sexo detalhe de tempo  valor de observação  \
# ...

# %%
df_negado.loc[:,'região ODS']
# Out:
# 0      Europa e América do Norte
# 1      Europa e América do Norte
# 2      Europa e América do Norte
# 3      Europa e América do Norte
# 4      Europa e América do Norte
#                  ...
# 250      América Latina e Caribe
# 251     Leste e Sudeste Asiático
# 252     Leste e Sudeste Asiático
# 253           África Subsaariana
# 254           África Subsaariana
# Name: região ODS, Length: 255, dtype: object

# %%
plt.figure(figsize=(12, 6))

# com tonalidades das barras definidas pela faixa etária

#contagem = df_negado[['area de referencia', 'valor de observação']].sort_values(by=['area de referencia', 'valor de observação'], ascending=False).head(0) 

sns.countplot(data = df_negado,
              x = 'região ODS',
              hue = 'valor de observação')

# definir texto do título e eixos x e y

plt.title('Relação de casamento não consentido por idade - regiões')
plt.xlabel('região ODS')
plt.ylabel('valor de observação')

# como o texto do eixo x é longo, podemos rotacioná-lo para melhorar a visualização

plt.xticks(rotation=330)

# plotar e definir texto da legenda

plt.legend(title = 'valor de observação')

plt.show()
# Out:
# C:\Users\Vida me surpreenda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Vida me surpreenda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Vida me surpreenda\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df_casamento = pd.merge(df_consentido, df_consentimento_negado, on='região ODS')
df_casamento
# Out:
#       descrição da area de refêrencia            x_x            y_x  \
# 0                             Albânia  2.006.660.928  4.113.897.007
# 1                             Albânia  2.006.660.928  4.113.897.007
# 2                             Albânia  2.006.660.928  4.113.897.007
# 3                             Albânia  2.006.660.928  4.113.897.007
# 4                             Albânia  2.006.660.928  4.113.897.007
# ...                               ...            ...            ...
# 10588                     Uzbequistão  6.311.944.558  4.177.560.518
# 10589                     Uzbequistão  6.311.944.558  4.177.560.518
# 10590                     Uzbequistão  6.311.944.558  4.177.560.518
# 10591                     Uzbequistão  6.311.944.558  4.177.560.518
# 10592                     Uzbequistão  6.311.944.558  4.177.560.518
#
#                       região ODS sexo_x detalhe de tempo_x  \
# 0      Europa e América do Norte      M          2012-2021
# ...

# %%
# Exportando a base final 
df_casamento.to_csv('base_final_casamento.csv', index=False)
